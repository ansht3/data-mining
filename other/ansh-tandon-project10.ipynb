# %% [markdown]
# # Project 10 -- Ansh Tandon

# %% [markdown]
# **TA Help:** John Smith, Alice Jones
#
# - Help with figuring out how to write a function.
#
# **Collaboration:** Friend1, Friend2
#
# - Helped figuring out how to load the dataset.
# - Helped debug error with my plot.

# %% [markdown]
# ## Question 1

# %%
# %sql sqlite:////anvil/projects/tdm/data/lahman/lahman.db

# %%
# not correct, figure it out aga
# %sql SELECT p.playerID, SUM(b.H) AS H, SUM(b.HR) AS HR, p.nameFirst, p.nameLast, p.awardID FROM People AS p JOIN Batting AS b ON p.playerID = b.playerID WHERE b.yearID = 2023 AND b.teamID = 'CHN' GROUP BY p.playerID
# Out:
#  * sqlite:////anvil/projects/tdm/data/lahman/lahman.db
# (sqlite3.OperationalError) no such column: p.awardID
# [SQL: SELECT p.playerID, SUM(b.H) AS H, SUM(b.HR) AS HR, p.nameFirst, p.nameLast, p.awardID FROM People AS p JOIN Batting AS b ON p.playerID = b.playerID WHERE b.yearID = 2023 AND b.teamID = 'CHN' GROUP BY p.playerID]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %%
# %sql SELECT p.playerID, p.awardID FROM AwardsPlayers AS p JOIN Batting AS b ON p.playerID = b.playerID WHERE b.yearID = 2023 AND b.teamID = 'CHN' GROUP BY p.playerID
# Out:
#  * sqlite:////anvil/projects/tdm/data/lahman/lahman.db
# Done.
# [('barnhtu01', 'Gold Glove'),
#  ('bellico01', 'Comeback Player of the Year'),
#  ('fulmemi01', 'Rookie of the Year'),
#  ('gomesya01', 'Silver Slugger'),
#  ('happia01', 'Gold Glove'),
#  ('hoernni01', 'Gold Glove'),
#  ('hosmeer01', 'All-Star Game MVP'),
#  ('mancitr01', 'Comeback Player of the Year'),
#  ('stromma01', 'Gold Glove'),
#  ('swansda01', 'Gold Glove')]

# %%
# final box where I figured out how to properly join awards players!
# %sql SELECT b.playerID, b.H, b.HR, p.nameFirst, p.nameLast, a.awardID FROM Batting AS b JOIN People AS p ON b.playerID = p.playerID JOIN AwardsPlayers AS a ON a.playerID = b.playerID AND a.yearID = b.yearID WHERE b.teamID = 'CHN' AND b.yearID = 2023
# Out:
#  * sqlite:////anvil/projects/tdm/data/lahman/lahman.db
# Done.
# [('bellico01', 153, 26, 'Cody', 'Bellinger', 'Comeback Player of the Year'),
#  ('bellico01', 153, 26, 'Cody', 'Bellinger', 'Silver Slugger'),
#  ('bellico01', 153, 26, 'Cody', 'Bellinger', 'TSN All-Star'),
#  ('happia01', 144, 21, 'Ian', 'Happ', 'Gold Glove'),
#  ('hoernni01', 175, 9, 'Nico', 'Hoerner', 'Gold Glove'),
#  ('swansda01', 138, 22, 'Dansby', 'Swanson', 'Gold Glove'),
#  ('swansda01', 138, 22, 'Dansby', 'Swanson', 'TSN All-Star')]

# %% [markdown]
# Markdown notes and sentences and analysis written here.

# %% [markdown]
# ## Question 2

# %%
# %sql SELECT b.playerID, SUM(b.HR), p.nameFirst, p.nameLast AS HR FROM Batting AS b JOIN Pitching AS m ON b.playerID = m.playerID AND b.yearID = m.yearID AND b.stint = m.stint JOIN People AS p ON p.playerID = m.playerID WHERE b.yearID = 2023 GROUP BY b.playerID, p.nameFirst, p.nameLast HAVING SUM(b.HR) > 30
# Out:
#  * sqlite:////anvil/projects/tdm/data/lahman/lahman.db
# Done.
# [('ohtansh01', 44, 'Shohei', 'Ohtani')]

# %% [markdown]
# Markdown notes and sentences and analysis written here.

# %% [markdown]
# ## Question 3

# %%
# %sql SELECT p.playerID, p.nameFirst, p.nameLast, SUM(b.R), SUM(b.SB), SUM(s.salary) FROM People AS p JOIN Batting AS b ON p.playerID = b.playerID JOIN Salaries AS s ON p.playerID = s.playerID WHERE p.nameFirst = 'Omar' AND p.nameLast = 'Vizquel'
# Out:
#  * sqlite:////anvil/projects/tdm/data/lahman/lahman.db
# Done.
# [('vizquom01', 'Omar', 'Vizquel', 34680, 9696, 1517056032.0)]

# %% [markdown]
# Markdown notes and sentences and analysis written here.

# %% [markdown]
# ## Question 4

# %%
# %sql SELECT p.playerID, SUM(b.H) AS total_hits, p.nameFirst, p.nameLast, SUM(ap.G_ALL) AS total_played FROM People AS p JOIN Batting AS b ON p.playerID = b.playerID JOIN Appearances AS ap ON p.playerID = ap.playerID GROUP BY p.playerID ORDER BY total_hits DESC LIMIT 5
# Out:
#  * sqlite:////anvil/projects/tdm/data/lahman/lahman.db
# Done.
# [('rosepe01', 106400, 'Pete', 'Rose', 89050),
#  ('cobbty01', 100536, 'Ty', 'Cobb', 72816),
#  ('ansonca01', 92745, 'Cap', 'Anson', 68148),
#  ('henderi01', 88595, 'Rickey', 'Henderson', 89349),
#  ('aaronha01', 86733, 'Hank', 'Aaron', 75854)]

# %%
# %sql SELECT p.playerID, SUM(b.HR) AS total_home_runs, p.nameFirst, p.nameLast, SUM(ap.G_ALL) AS total_played FROM People AS p JOIN Batting AS b ON p.playerID = b.playerID JOIN Appearances AS ap ON p.playerID = ap.playerID GROUP BY p.playerID ORDER BY total_home_runs DESC LIMIT 5
# Out:
#  * sqlite:////anvil/projects/tdm/data/lahman/lahman.db
# Done.
# [('aaronha01', 17365, 'Hank', 'Aaron', 75854),
#  ('bondsba01', 16764, 'Barry', 'Bonds', 65692),
#  ('pujolal01', 16169, 'Albert', 'Pujols', 70840),
#  ('ruthba01', 15708, 'Babe', 'Ruth', 55088),
#  ('rodrial01', 15312, 'Alex', 'Rodriguez', 61248)]

# %% [markdown]
# Markdown notes and sentences and analysis written here.

# %% [markdown]
# ## Question 5

# %%
# %sql SELECT p.playerID, p.nameFirst, p.nameLast, f.yearID, f.ballots, f.needed, f.votes, f.inducted FROM People AS p JOIN CollegePlaying AS cp ON p.playerID = cp.playerID JOIN HallofFame AS f ON p.playerID = f.playerID WHERE cp.schoolID = 'purdue' GROUP BY p.playerID
# Out:
#  * sqlite:////anvil/projects/tdm/data/lahman/lahman.db
# Done.
# [('allenbe01', 'Bernie', 'Allen', 1979, 432, 324, 0, 'N')]

# %% [markdown]
# Markdown notes and sentences and analysis written here.

# %% [markdown]
# ## Pledge
#
# By submitting this work I hereby pledge that this is my own, personal work. I've acknowledged in the designated place at the top of this file all sources that I used to complete said work, including but not limited to: online resources, books, and electronic communications. I've noted all collaboration with fellow students and/or TA's. I did not copy or plagiarize another's work.
#
# > As a Boilermaker pursuing academic excellence, I pledge to be honest and true in all that I do. Accountable together – We are Purdue.
