# %%
# %%bash
# awk -F';' '{ total += $22 } END { print total }'  /anvil/projects/tdm/data/iowa_liquor_sales/iowa_liquor_sales_cleaner.txt
# Out:
# 3.86987e+09

# %%
# %%bash
# awk -F'|' '{ total += $15 } END { print total }' /anvil/projects/tdm/data/election/itcont1980.txt
# Out:
# 204280929

# %%
# %%bash
# awk -F'|' '{ total += $15 } END { print total }' /anvil/projects/tdm/data/election/itcont*.txt
# Out:
# 6.27017e+10

# %%
# %%bash
# awk -F',' '{ totalscores += $NF; totallines++ } END { print totalscores / totallines }' /anvil/projects/tdm/data/beer/reviews.csv
# Out:
# 3.88981

# %%
# %%bash
# grep SOUTH /anvil/projects/tdm/data/8451/The_Complete_Journey_2_Master/5000_transactions.csv | awk -F',' '{ total += $5 } END { print total }'
# Out:
# 7.95792e+06

# %%
# %%bash
# grep EAST /anvil/projects/tdm/data/8451/The_Complete_Journey_2_Master/5000_transactions.csv | awk -F',' '{ total += $5 } END { print total }'
# Out:
# 1.16994e+07

# %%
# %%bash
# grep WEST /anvil/projects/tdm/data/8451/The_Complete_Journey_2_Master/5000_transactions.csv | awk -F',' '{ total += $5 } END { print total }'
# Out:
# 9.68011e+06

# %%
# %%bash
# grep CENTRAL /anvil/projects/tdm/data/8451/The_Complete_Journey_2_Master/5000_transactions.csv | awk -F',' '{ total += $5 } END { print total }'
# Out:
# 8.89731e+06

# %%
# %%bash
# awk -F, '{print "flights from "$17" to "$18}' /anvil/projects/tdm/data/flights/subset/1990.csv | sort | uniq -c | sort -n | tail -10
# Out:
#   10133 flights from ORD to MSP
#   10157 flights from LAS to LAX
#   10298 flights from PHX to LAS
#   10344 flights from LGA to ORD
#   10475 flights from HOU to DAL
#   10559 flights from LAX to LAS
#   12938 flights from PHX to LAX
#   13121 flights from LAX to PHX
#   25779 flights from LAX to SFO
#   26134 flights from SFO to LAX
