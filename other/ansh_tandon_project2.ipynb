# %%
# %%bash
#
# # prints line count, then word count, then byte count for `2012.csv`
# wc /anvil/projects/tdm/data/stackoverflow/processed/2012.csv
#
# # prints just the line count for `2012.csv`
# wc -l /anvil/projects/tdm/data/stackoverflow/processed/2012.csv
#
# # prints just the word count for `2012.csv`
# wc -w /anvil/projects/tdm/data/stackoverflow/processed/2012.csv
#
# # prints just the byte count for `2012.csv`
# wc -c /anvil/projects/tdm/data/stackoverflow/processed/2012.csv
# Out:
#    6244  155215 2153349 /anvil/projects/tdm/data/stackoverflow/processed/2012.csv
# 6244 /anvil/projects/tdm/data/stackoverflow/processed/2012.csv
# 155215 /anvil/projects/tdm/data/stackoverflow/processed/2012.csv
# 2153349 /anvil/projects/tdm/data/stackoverflow/processed/2012.csv

# %%
# %%bash
#
# # print the number of bytes that all of the processed directory is taking up
# du -b /anvil/projects/tdm/data/stackoverflow/processed
#
# # prints the number of kilobytes that the processed directory is taking up
# du --block-size=KB /anvil/projects/tdm/data/stackoverflow/processed
#
# # prints the number of kilobytes that each file in the processed directory is taking up
# du --block-size=KB -a /anvil/projects/tdm/data/stackoverflow/processed
# Out:
# 3895654	/anvil/projects/tdm/data/stackoverflow/processed
# 4720kB	/anvil/projects/tdm/data/stackoverflow/processed
# 2622kB	/anvil/projects/tdm/data/stackoverflow/processed/2012.csv
# 1049kB	/anvil/projects/tdm/data/stackoverflow/processed/test.csv
# 1049kB	/anvil/projects/tdm/data/stackoverflow/processed/2011.csv
# 4720kB	/anvil/projects/tdm/data/stackoverflow/processed

# %%
# %%bash
# head -n1 /anvil/projects/tdm/data/flights/subset/1987.csv >$SCRATCH/myflights.csv # creating the new myflights csv from 1987 csv in SCRATCH directory

# %%
# %%bash
# grep -h -v Year /anvil/projects/tdm/data/flights/subset/[12]*.csv >>$SCRATCH/myflights.csv # appending to the myflights csv

# %%
# %%bash
# ls -la $SCRATCH/myflights.csv # checking size of file
# Out:
# -rw-r--r-- 1 x-atandon x-cis220051 11569874864 Aug 30 18:58 /anvil/scratch/x-atandon/myflights.csv

# %%
# %%bash
# wc $SCRATCH/myflights.csv # details total lines in file
# Out:
#   118914459   119301248 11569874864 /anvil/scratch/x-atandon/myflights.csv

# %%
# %%bash
# head $SCRATCH/myflights.csv # head of the myflights csv
# Out:
# Year,Month,DayofMonth,DayOfWeek,DepTime,CRSDepTime,ArrTime,CRSArrTime,UniqueCarrier,FlightNum,TailNum,ActualElapsedTime,CRSElapsedTime,AirTime,ArrDelay,DepDelay,Origin,Dest,Distance,TaxiIn,TaxiOut,Cancelled,CancellationCode,Diverted,CarrierDelay,WeatherDelay,NASDelay,SecurityDelay,LateAircraftDelay
# 1987,10,14,3,741,730,912,849,PS,1451,NA,91,79,NA,23,11,SAN,SFO,447,NA,NA,0,NA,0,NA,NA,NA,NA,NA
# 1987,10,15,4,729,730,903,849,PS,1451,NA,94,79,NA,14,-1,SAN,SFO,447,NA,NA,0,NA,0,NA,NA,NA,NA,NA
# 1987,10,17,6,741,730,918,849,PS,1451,NA,97,79,NA,29,11,SAN,SFO,447,NA,NA,0,NA,0,NA,NA,NA,NA,NA
# 1987,10,18,7,729,730,847,849,PS,1451,NA,78,79,NA,-2,-1,SAN,SFO,447,NA,NA,0,NA,0,NA,NA,NA,NA,NA
# 1987,10,19,1,749,730,922,849,PS,1451,NA,93,79,NA,33,19,SAN,SFO,447,NA,NA,0,NA,0,NA,NA,NA,NA,NA
# 1987,10,21,3,728,730,848,849,PS,1451,NA,80,79,NA,-1,-2,SAN,SFO,447,NA,NA,0,NA,0,NA,NA,NA,NA,NA
# 1987,10,22,4,728,730,852,849,PS,1451,NA,84,79,NA,3,-2,SAN,SFO,447,NA,NA,0,NA,0,NA,NA,NA,NA,NA
# ...

# %%
# %%bash
# mkdir $SCRATCH/myfolder # creates a new directory

# %%
# %%bash
# cp /anvil/projects/tdm/data/flights/subset/[12]*.csv $SCRATCH/myfolder

# %%
# %%bash
# head -n1 $SCRATCH/myfolder/1987.csv >$SCRATCH/myfolder/myflightsremix.csv

# %%
# %%bash
# grep -h -v Year $SCRATCH/myfolder/[12]*.csv >>$SCRATCH/myfolder/myflightsremix.csv

# %%
# %%bash
# ls -la $SCRATCH/myfolder/myflightsremix.csv
# Out:
# -rw-r--r-- 1 x-atandon x-cis220051 11569874864 Aug 30 19:01 /anvil/scratch/x-atandon/myfolder/myflightsremix.csv

# %%
# if you re-run steps, e.g., while building your template,
# and you already have $SCRATCH/myfolder created, then you might need to delete it before re-building!
# you can do that with rm -r $SCRATCH/myfolder

# %%
# %%bash
# cmp $SCRATCH/myflights.csv $SCRATCH/myfolder/myflightsremix.csv

# %%
# cmp returns the first difference in two files, or just runs and returns NOTHIN if the files are identical.
# so we hope that it returns nothing in this case! (i.e., we hope that it finds no differences)

# %%
# %%bash
# wc -l $SCRATCH/myflights.csv $SCRATCH/myfolder/myflightsremix.csv
# Out:
#   118914459 /anvil/scratch/x-atandon/myflights.csv
#   118914459 /anvil/scratch/x-atandon/myfolder/myflightsremix.csv
#   237828918 total

# %%
# %%bash
# wc $SCRATCH/myflights.csv $SCRATCH/myfolder/myflightsremix.csv
# Out:
#   118914459   119301248 11569874864 /anvil/scratch/x-atandon/myflights.csv
#   118914459   119301248 11569874864 /anvil/scratch/x-atandon/myfolder/myflightsremix.csv
#   237828918   238602496 23139749728 total

# %%
# %%bash
# ls -la $SCRATCH/myflights.csv $SCRATCH/myfolder/myflightsremix.csv
# Out:
# -rw-r--r-- 1 x-atandon x-cis220051 11569874864 Aug 30 18:58 /anvil/scratch/x-atandon/myflights.csv
# -rw-r--r-- 1 x-atandon x-cis220051 11569874864 Aug 30 19:01 /anvil/scratch/x-atandon/myfolder/myflightsremix.csv

# %%
# %%bash
# du -b $SCRATCH/myflights.csv
# Out:
# 11569874864	/anvil/scratch/x-atandon/myflights.csv

# %%
# %%bash
# du --block-size=KB $SCRATCH/myflights.csv
# Out:
# 11569988kB	/anvil/scratch/x-atandon/myflights.csv

# %%
# %%bash
# du --block-size=KB $SCRATCH/myfolder/myflightsremix.csv
# Out:
# 11569988kB	/anvil/scratch/x-atandon/myfolder/myflightsremix.csv

# %%
# %%bash
# ls -la $SCRATCH
# Out:
# total 11299842
# drwx------    3 x-atandon x-cis220051        4096 Aug 30 19:01 .
# drwxr-xr-x 9210 nobody    nogroup          524288 Aug 30 18:30 ..
# -rw-r--r--    1 x-atandon x-cis220051 11569874864 Aug 30 18:58 myflights.csv
# drwxr-xr-x    2 x-atandon x-cis220051        4096 Aug 30 19:01 myfolder

# %%
# %%bash
# rm -r $SCRATCH/myfolder

# %%
# %%bash
# ls -la $SCRATCH
# Out:
# total 11299841
# drwx------    2 x-atandon x-cis220051        4096 Aug 30 19:07 .
# drwxr-xr-x 9210 nobody    nogroup          524288 Aug 30 18:30 ..
# -rw-r--r--    1 x-atandon x-cis220051 11569874864 Aug 30 18:58 myflights.csv

# %%
# %%bash
# cp /anvil/projects/tdm/data/election/itcont*.txt $SCRATCH

# %%
# %%bash
# ls -la $SCRATCH
# Out:
# total 53093889
# drwx------    2 x-atandon x-cis220051        4096 Aug 30 19:09 .
# drwxr-xr-x 9210 nobody    nogroup          524288 Aug 30 18:30 ..
# -rw-r--r--    1 x-atandon x-cis220051    37558800 Aug 30 19:09 itcont1980.txt
# -rw-r--r--    1 x-atandon x-cis220051    20660307 Aug 30 19:09 itcont1982.txt
# -rw-r--r--    1 x-atandon x-cis220051    31137003 Aug 30 19:09 itcont1984.txt
# -rw-r--r--    1 x-atandon x-cis220051    34396801 Aug 30 19:09 itcont1986.txt
# -rw-r--r--    1 x-atandon x-cis220051    53066338 Aug 30 19:09 itcont1988.txt
# -rw-r--r--    1 x-atandon x-cis220051    64648648 Aug 30 19:09 itcont1990.txt
# -rw-r--r--    1 x-atandon x-cis220051   107021489 Aug 30 19:09 itcont1992.txt
# -rw-r--r--    1 x-atandon x-cis220051   101905485 Aug 30 19:09 itcont1994.txt
# -rw-r--r--    1 x-atandon x-cis220051   148872758 Aug 30 19:09 itcont1996.txt
# -rw-r--r--    1 x-atandon x-cis220051   122709219 Aug 30 19:09 itcont1998.txt
# ...

# %%
# %%bash
# mkdir $SCRATCH/mytemporarydirectory

# %%
# %%bash
# mv $SCRATCH/itcont*.txt $SCRATCH/mytemporarydirectory

# %%
# %%bash
# ls -la $SCRATCH/mytemporarydirectory
# Out:
# total 41794050
# drwxr-xr-x 2 x-atandon x-cis220051        4096 Aug 30 19:13 .
# drwx------ 3 x-atandon x-cis220051        4096 Aug 30 19:13 ..
# -rw-r--r-- 1 x-atandon x-cis220051    37558800 Aug 30 19:09 itcont1980.txt
# -rw-r--r-- 1 x-atandon x-cis220051    20660307 Aug 30 19:09 itcont1982.txt
# -rw-r--r-- 1 x-atandon x-cis220051    31137003 Aug 30 19:09 itcont1984.txt
# -rw-r--r-- 1 x-atandon x-cis220051    34396801 Aug 30 19:09 itcont1986.txt
# -rw-r--r-- 1 x-atandon x-cis220051    53066338 Aug 30 19:09 itcont1988.txt
# -rw-r--r-- 1 x-atandon x-cis220051    64648648 Aug 30 19:09 itcont1990.txt
# -rw-r--r-- 1 x-atandon x-cis220051   107021489 Aug 30 19:09 itcont1992.txt
# -rw-r--r-- 1 x-atandon x-cis220051   101905485 Aug 30 19:09 itcont1994.txt
# -rw-r--r-- 1 x-atandon x-cis220051   148872758 Aug 30 19:09 itcont1996.txt
# -rw-r--r-- 1 x-atandon x-cis220051   122709219 Aug 30 19:09 itcont1998.txt
# -rw-r--r-- 1 x-atandon x-cis220051   208233532 Aug 30 19:09 itcont2000.txt
# ...

# %%
# %%bash
# ls -la $SCRATCH
# Out:
# total 11299842
# drwx------    3 x-atandon x-cis220051        4096 Aug 30 19:13 .
# drwxr-xr-x 9210 nobody    nogroup          524288 Aug 30 18:30 ..
# -rw-r--r--    1 x-atandon x-cis220051 11569874864 Aug 30 18:58 myflights.csv
# drwxr-xr-x    2 x-atandon x-cis220051        4096 Aug 30 19:13 mytemporarydirectory

# %%
# %%bash
# cat $SCRATCH/mytemporarydirectory/itcont*.txt >$SCRATCH/mytemporarydirectory/myelectiondata.txt

# %%
# %%bash
# ls -la $SCRATCH/mytemporarydirectory
# Out:
# total 83581954
# drwxr-xr-x 2 x-atandon x-cis220051        4096 Aug 30 19:17 .
# drwx------ 3 x-atandon x-cis220051        4096 Aug 30 19:13 ..
# -rw-r--r-- 1 x-atandon x-cis220051    37558800 Aug 30 19:09 itcont1980.txt
# -rw-r--r-- 1 x-atandon x-cis220051    20660307 Aug 30 19:09 itcont1982.txt
# -rw-r--r-- 1 x-atandon x-cis220051    31137003 Aug 30 19:09 itcont1984.txt
# -rw-r--r-- 1 x-atandon x-cis220051    34396801 Aug 30 19:09 itcont1986.txt
# -rw-r--r-- 1 x-atandon x-cis220051    53066338 Aug 30 19:09 itcont1988.txt
# -rw-r--r-- 1 x-atandon x-cis220051    64648648 Aug 30 19:09 itcont1990.txt
# -rw-r--r-- 1 x-atandon x-cis220051   107021489 Aug 30 19:09 itcont1992.txt
# -rw-r--r-- 1 x-atandon x-cis220051   101905485 Aug 30 19:09 itcont1994.txt
# -rw-r--r-- 1 x-atandon x-cis220051   148872758 Aug 30 19:09 itcont1996.txt
# -rw-r--r-- 1 x-atandon x-cis220051   122709219 Aug 30 19:09 itcont1998.txt
# -rw-r--r-- 1 x-atandon x-cis220051   208233532 Aug 30 19:09 itcont2000.txt
# ...

# %%
# %%bash
# wc $SCRATCH/mytemporarydirectory/myelectiondata.txt
# Out:
#   229169299  1385963208 42790681570 /anvil/scratch/x-atandon/mytemporarydirectory/myelectiondata.txt

# %%
# %%bash
# head /anvil/projects/tdm/data/flights/subset/1987.csv
# Out:
# Year,Month,DayofMonth,DayOfWeek,DepTime,CRSDepTime,ArrTime,CRSArrTime,UniqueCarrier,FlightNum,TailNum,ActualElapsedTime,CRSElapsedTime,AirTime,ArrDelay,DepDelay,Origin,Dest,Distance,TaxiIn,TaxiOut,Cancelled,CancellationCode,Diverted,CarrierDelay,WeatherDelay,NASDelay,SecurityDelay,LateAircraftDelay
# 1987,10,14,3,741,730,912,849,PS,1451,NA,91,79,NA,23,11,SAN,SFO,447,NA,NA,0,NA,0,NA,NA,NA,NA,NA
# 1987,10,15,4,729,730,903,849,PS,1451,NA,94,79,NA,14,-1,SAN,SFO,447,NA,NA,0,NA,0,NA,NA,NA,NA,NA
# 1987,10,17,6,741,730,918,849,PS,1451,NA,97,79,NA,29,11,SAN,SFO,447,NA,NA,0,NA,0,NA,NA,NA,NA,NA
# 1987,10,18,7,729,730,847,849,PS,1451,NA,78,79,NA,-2,-1,SAN,SFO,447,NA,NA,0,NA,0,NA,NA,NA,NA,NA
# 1987,10,19,1,749,730,922,849,PS,1451,NA,93,79,NA,33,19,SAN,SFO,447,NA,NA,0,NA,0,NA,NA,NA,NA,NA
# 1987,10,21,3,728,730,848,849,PS,1451,NA,80,79,NA,-1,-2,SAN,SFO,447,NA,NA,0,NA,0,NA,NA,NA,NA,NA
# 1987,10,22,4,728,730,852,849,PS,1451,NA,84,79,NA,3,-2,SAN,SFO,447,NA,NA,0,NA,0,NA,NA,NA,NA,NA
# ...

# %%
# %%bash
# cut -d, -f17,18 /anvil/projects/tdm/data/flights/subset/[12]*.csv >$SCRATCH/myoriginsanddestinations.txt

# %%
# %%bash
# head $SCRATCH/myoriginsanddestinations.txt
# Out:
# Origin,Dest
# SAN,SFO
# SAN,SFO
# SAN,SFO
# SAN,SFO
# SAN,SFO
# SAN,SFO
# SAN,SFO
# SAN,SFO
# SAN,SFO

# %%
# %%bash
# tail $SCRATCH/myoriginsanddestinations.txt
# Out:
# GSO,ATL
# ATL,MCI
# CVG,BOS
# BOS,CVG
# CVG,BOS
# BOS,CVG
# CVG,BOS
# BOS,CVG
# CVG,BOS
# BWI,CVG

# %%
# %%bash
# ls -la $SCRATCH/myoriginsanddestinations.txt
# Out:
# -rw-r--r-- 1 x-atandon x-cis220051 951315928 Aug 30 20:09 /anvil/scratch/x-atandon/myoriginsanddestinations.txt

# %%
# %%bash
# wc $SCRATCH/myoriginsanddestinations.txt
# Out:
# 118914480 118914480 951315928 /anvil/scratch/x-atandon/myoriginsanddestinations.txt

# %%
# %%bash
# sort $SCRATCH/myoriginsanddestinations.txt >$SCRATCH/mysortedoriginsanddestinations.txt

# %%
# %%bash
# head $SCRATCH/mysortedoriginsanddestinations.txt
# Out:
# ABE,ALB
# ABE,ALB
# ABE,ATL
# ABE,ATL
# ABE,ATL
# ABE,ATL
# ABE,ATL
# ABE,ATL
# ABE,ATL
# ABE,ATL

# %%
# %%bash
# tail $SCRATCH/mysortedoriginsanddestinations.txt
# Out:
# YUM,SLC
# YUM,SLC
# YUM,SLC
# YUM,SLC
# YUM,SLC
# YUM,SLC
# YUM,SLC
# YUM,SLC
# YUM,SLC
# YUM,SLC

# %%
# %%bash
# uniq -c $SCRATCH/mysortedoriginsanddestinations.txt >$SCRATCH/mycounts.txt

# %%
# %%bash
# head $SCRATCH/mycounts.txt
# Out:
#       2 ABE,ALB
#   15966 ABE,ATL
#    1627 ABE,AVP
#       1 ABE,AZO
#       1 ABE,BDL
#       1 ABE,BHM
#    2559 ABE,BWI
#    5375 ABE,CLE
#    6917 ABE,CLT
#    6732 ABE,CVG

# %%
# %%bash
# tail $SCRATCH/mycounts.txt
# Out:
#       1 YKM,SFO
#       1 YKM,SJC
#     592 YKM,SLC
#       1 YUM,GJT
#    1341 YUM,IPL
#     434 YUM,LAS
#    6236 YUM,LAX
#   12251 YUM,PHX
#       3 YUM,PSP
#     263 YUM,SLC

# %%
# %%bash
# sort -n $SCRATCH/mycounts.txt >$SCRATCH/mysortedcounts.txt

# %%
# %%bash
# head $SCRATCH/mysortedcounts.txt
# Out:
#       1 ABE,AZO
#       1 ABE,BDL
#       1 ABE,BHM
#       1 ABE,GRR
#       1 ABE,IND
#       1 ABE,ROC
#       1 ABE,SBN
#       1 ABI,LAX
#       1 ABI,TYR
#       1 ABI,VCT

# %%
# %%bash
# tail $SCRATCH/mysortedcounts.txt
# Out:
#  232467 LAS,PHX
#  233977 PHX,LAS
#  242933 MSP,ORD
#  243470 ORD,MSP
#  272681 LAX,PHX
#  273286 PHX,LAX
#  278653 LAS,LAX
#  284494 LAX,LAS
#  328105 LAX,SFO
#  329370 SFO,LAX

# %%
# %%bash
# cut -d, -f7 /anvil/projects/tdm/data/8451/The_Complete_Journey_2_Master/5000_transactions.csv >$SCRATCH/tempfile.txt

# %%
# %%bash
# head /anvil/projects/tdm/data/8451/The_Complete_Journey_2_Master/5000_transactions.csv
# Out:
# BASKET_NUM              ,HSHD_NUM        ,PURCHASE_,PRODUCT_NUM                 ,     SPEND,     UNITS,STORE_R,  WEEK_NUM,YEAR
# 000024                  ,1809            ,03-JAN-16,5817389                     ,      -1.5,        -1,SOUTH  ,         1,2016
# 000024                  ,1809            ,03-JAN-16,5829886                     ,      -1.5,        -1,SOUTH  ,         1,2016
# 000034                  ,1253            ,03-JAN-16,0539501                     ,      2.19,         1,EAST   ,         1,2016
# 000060                  ,1595            ,03-JAN-16,5260099                     ,       .99,         1,WEST   ,         1,2016
# 000060                  ,1595            ,03-JAN-16,4535660                     ,       2.5,         2,WEST   ,         1,2016
# 000168                  ,3393            ,03-JAN-16,5602916                     ,       4.5,         1,SOUTH  ,         1,2016
# ...

# %%
# %%bash
# head $SCRATCH/tempfile.txt
# Out:
# STORE_R
# SOUTH
# SOUTH
# EAST
# WEST
# WEST
# SOUTH
# SOUTH
# SOUTH
# EAST

# %%
# %%bash
# sort $SCRATCH/tempfile.txt >$SCRATCH/sortedtempfile.txt

# %%
# %%bash
# uniq -c $SCRATCH/sortedtempfile.txt
# Out:
# 2463343 CENTRAL
# 3263360 EAST
# 2221500 SOUTH
#       1 STORE_R
# 2677350 WEST

# %%
# %%bash
# sort -n $SCRATCH/sortedtempfile.txt >$SCRATCH/newtempsortedfile.txt
