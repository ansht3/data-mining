# %% [markdown]
# # Project 14 -- Ansh Tandon

# %% [markdown]
# **TA Help:** John Smith, Alice Jones
#
# - Help with figuring out how to write a function.
#
# **Collaboration:** Friend1, Friend2
#
# - Helped figuring out how to load the dataset.
# - Helped debug error with my plot.

# %% [markdown]
# ## Question 1

# %% [markdown]
# Question:
#
# The Data Mine team is writing a Data Mine book to be (hopefully) published in 2025. We would love to have a couple of paragraphs about your Data Mine experience. What aspects of The Data Mine made the biggest impact on your academic, personal, and/or professional career? Would you recommend The Data Mine to a friend and/or would you recommend The Data Mine to colleagues in industry, and why? You are welcome to cover other topics too! Please also indicate (yes/no) whether it would be OK to publish your comments in our forthcoming Data Mine book in 2025.
#
#
# Answer:
#
# My biggest takeaway from the Data Mine has been the skills and technologies I've learned throughout the journey. Regardless of whether I was doing work with the seminar or meeting with groups for the corporate partners project, Data Mine has been able to fuel my drive to solve great challenges with technological solutions. I've been able to increase my knowledge through working on industry-impactful project, where I've learned more about data science and analytics tools in this course with Bash SQL and more, vital to be prominent in the technology industry. Not only that, the Data Mine has been able to impact my professional career, as whenever I take technical interview for roles related to analytics or backend, I feel confident approaching those interviews, because of all of the technical projects I have done on real data sets, which have been similar to what has appeared on technical interviews.
#
# With that, I would definitely recommend The Data Mine to my friends and peers, because I believe that they'd be able to enhance themselves with new tools that they never experienced before. At the same time, I think that my friends would really enjoy the outside events that are present in Data Mine, because through those they'd learn more about other technical related fields, like artificial inteligence and robotics. As a result, having acces to adequate materials to effectively understand difficult concepts after lectures is something that I really admire with the Data Mine, and I believe has allowed me to effectively ensure that I can complete my projects.

# %% [markdown]
# ## Question 2

# %% [markdown]
# Question:
#
# Reflecting on your experience working with different datasets, which one did you find most enjoyable, and why? Discuss how this dataset’s features influenced your analysis and visualization strategies. Illustrate your explanation with an example from one question that you worked on, using the dataset.
#
# Answer:
#
# The dataset that I found the most enjoyable was the 5000_transactions.csv data, because of the variety that was present in the data. This was because it helped me internalize the -F, command, where I was able to see that I can actually split data with the scomma specifier. From that, since there were many data attributes for each particular data row, I was able to learn more about how to do calculations, where I can utilize my prior knowledge of variables and actually go through all of the data withinn '{}'. The datasets features included things such as the store region, and actual value for a given store, as well as different IDs that are relevant to that particular store. An example where I was able to illustrate my explanation was with using the grep command, which is here.
# grep CENTRAL /anvil/projects/tdm/data/8451/The_Complete_Journey_2_Master/5000_transactions.csv | awk -F',' '{ total += $5 } END { print total }'
# From the following, I was able to learn how to filter based on the given region of the store, and then go ahead and actually calculate the total amount in the given SPEND colomun. By doing so, I was able to actually utilize the dataset to conduct proper analysis that I needed for the question.

# %% [markdown]
# ## Question 3

# %% [markdown]
# Question:
#
# While working on the projects, how did you validate the results that your code produced? For instance, did you try to solve problems in 2 different ways? Or did you try to make summaries and/or visualizations? How did you prefer to explore data and learn about data? Are there better ways that you would suggest for future students (and for our team too)? Please illustrate your approach using an example from one problem that you addressed this semester.
#
# Answer:
#
# On the 9th project involving utilize SQL with the lahman.db, I needed to figure out how to join two different tables together, Batting and People, in order to get the playerID of a specific player from 2023. In order to combat this, my first approach involved selecting the player ID, and then from there actually joining the tables with the FROM command. Finally, I went ahead and put the conditions that needed to be satisfied, which included ensuring the playerID wer in both tables, as well as match the particular yearID and stint for the season. Finally, I was able to filter the records and gropu the data based on the playerID with WHERE and GROUP BY, as well as filter the final sum to only display if it was greater than 30, as indicated in the problem.
#
# For my second approach, I first went ahead and aggregated the total hom runs that were possible, based on all of the parameters like the playerID, yearID and the stint. From there, I got the unique ones that were present into a final table, where I then joined Batting table with the new final table. This allowed me to finally filer based on the sum, which allowed me to get the same output. This allowed me to validate my results, as I was able to get the same output for the both.
#
# For me personally, I preferred to explore the data like I did in the first approach, as it allowed me to use my intuition so that I can join the tables as stated, and then go ahead and filter out to get the final result. For the future, I don't have any suggestions, as this question was intuitive, but an additional aspect could be showcasing an example of the filtering logic, as that was one of the more difficult aspects of the question that required more logical reasoning.

# %% [markdown]
# ## Question 4

# %% [markdown]
# Question:
#
# Reflecting on the projects that you completed, which question(s) did you feel were most confusing, and how could they be made clearer? Please cite specific questions and explain both how they confused you and how you would recommend improving them.
#
# Answer:
# The questions that I seemed the most confused involved two of the questions in project 10, as I needed to join more than 3 tables for question 2 and question 3, which was I skill that I didn't learn previously in SQL. As a result, I needed to go ahead and go through SQL documention to figure out examples to get a clear understanding, which involved ensuring that I include AS and ON commands between the three joins. Before, I was trying to join the three tables, but the new table I didn't repeat a variable name, which was creating errors within my code. I think this could be clearer in the future, as with an additional example to showcase how the JOIN command can be modified for different applications would allow me to internalize what my approach should be.

# %%
# code here

# %% [markdown]
# Markdown notes and sentences and analysis written here.

# %% [markdown]
# ## Question 5

# %% [markdown]
# Question:
#
# Please identify 3 skills or topics related to the bash shell, or databases, or data science (in general) that you wish we had covered in our projects. For each, please provide an example that illustrates your interests, and the reason that you think they would be beneficial.
#
# Answer:
# First, I think an advanced database topic that could be covered is recurisve queries that involve Common Table Expressions. This is because in data engineering and data pipeline development, having an understanding of going through data that has multiple aggregation levels, which is present in many industry based projcts. Having an understanding of CTEs would allow me to utilize tree data structures, which is something I've learned in my upper level CS classes, in order to have project that have larger impact. An example of my interest would involve implementing this in a project that I did in my CS class, which is where we had a e-commerce platform with data for all of the users that use the platform. As a result, I would go ahead and get information, like the average cost of items that are ordered on the platform, allowing me to make more meaningful insights with a faster run time.
#
# Second, I would like to explore error handling within Bash, as there were many instances where the code would creat a segmentation fault if there was an instance wheer the data was not split properly. With that, gaining technical knowledge and expertise within making scripts that are robust with error handling can help me be a better embedded software analyst, a career path I plan on pursuing. An applicaiton where this would be valid would involve working with flag commands like -o pipefail, which would alow me to figure out the errors based on the output logs.
#
# Finally, a topic that I would to explore in data science in general is linear regression, as understanding how to interpret different correlations within data to see whether they fit a trend is a skill that is essential for a lot of corporate work that is being done. A model that I think we could have had exposure in R or another programing language would be least squares model, as it would allow me to see whether certain coefficients are valid, letting me see if things like the slope for the given variables are valid. An example of this that I'd like to do to explore my interests would be to calculate the correlation between numerical rows that have height data for different human group types, and seeing if a pair of columns within a dataset has a relation that is statistically significant or not.

# %% [markdown]
# ## Pledge
#
# By submitting this work I hereby pledge that this is my own, personal work. I've acknowledged in the designated place at the top of this file all sources that I used to complete said work, including but not limited to: online resources, books, and electronic communications. I've noted all collaboration with fellow students and/or TA's. I did not copy or plagiarize another's work.
#
# > As a Boilermaker pursuing academic excellence, I pledge to be honest and true in all that I do. Accountable together – We are Purdue.
