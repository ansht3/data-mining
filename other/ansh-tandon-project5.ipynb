# %%
# %%bash
# cut -d',' -f9 /anvil/projects/tdm/data/flights/subset/[12]*.csv | sort | uniq -c | sort -n
# Out:
#      22 UniqueCarrier
#   70622 ML (1)
#   83617 PS
#  154381 AQ
#  208420 TZ
#  230824 HA
#  271876 F9
#  316167 PA (1)
#  347210 9E
#  682728 B6
#  684812 YV
#  693047 DH
#  873957 PI
#  919785 EA
# 1090310 FL
# 1338503 OH
# 1508980 EV
# 2114556 XE
# 2718878 OO
# 2776804 AS
# 3632062 MQ
# 3636682 HP
# 3757747 TW
# 7950035 CO
# 10067774 NW
# 13004338 UA
# 13775480 US
# 14584281 AA
# 15173234 WN
# 16247348 DL

# %%
# %%bash
# cut -d',' -f11 /anvil/projects/tdm/data/flights/subset/[12]*.csv | sort | uniq | wc -l
# Out:
# 12734

# %%
# %%bash
# cut -d',' -f4 /anvil/projects/tdm/data/8451/The_Complete_Journey_2_Master/5000_transactions.csv | tail -n +2 | sort -u | wc -l
# Out:
# 151141

# %%
# %%bash
# cut -d'|' -f1 /anvil/projects/tdm/data/election/itcont*.txt | sort | uniq | wc -l
# Out:
# 47787

# %%
# %%bash
# cut -d'|' -f1 /anvil/projects/tdm/data/election/itcont*.txt | sort | uniq -c | sort -nr | head -1
# Out:
# 50696691 C00401224

# %%
# %%bash
# grep -iE 'Lafayette|West Lafayette' /anvil/projects/tdm/data/beer/breweries.csv
# Out:
# 51616,Brokerage Brewing Company,West Lafayette,IN,US,No notes at this time.,"Brewery, Bar, Beer-to-go"
# 32900,Barren Hill Tavern & Brewery,Lafayette Hill,PA,US,No notes at this time.,"Brewery, Bar, Eatery"
# 24072,Copper Crow Brewing Company,Lafayette Hill,PA,US,No notes at this time.,Brewery
# 11468,Bo's Barbecue,Lafayette,CA,US,No notes at this time.,"Bar, Eatery"
# 30699,Village Bottle Shoppe #3,West Lafayette,IN,US,No notes at this time.,Store
# 40401,Harry's Chocolate Shop,West Lafayette,IN,US,No notes at this time.,"Bar, Eatery"
# 25532,Diablo Foods,Lafayette,CA,US,No notes at this time.,Store
# 26371,Walk-On's,Lafayette,LA,US,No notes at this time.,"Bar, Eatery"
# 34312,The Post Brewing Co.,Lafayette,CO,US,No notes at this time.,"Brewery, Bar, Eatery, Beer-to-go"
# 22055,Chow Restaurant,Lafayette,CA,US,No notes at this time.,Bar
# 16648,Knickerbocker Saloon,Lafayette,IN,US,No notes at this time.,"Bar, Eatery"
# ...

# %%
# %%bash
# cat /anvil/projects/tdm/data/icecream/combined/reviews.csv | tr ' ' '\n' | grep -oE '\w+' | sort | uniq -c | sort -nr | head -n 25
# Out:
#   90407 0
#   40448 I
#   35138 the
#   27055 and
#   25742 5
#   22220 it
#   19534 a
#   19148 cream
#   19005 ice
#   18812 is
#   18190 to
#   17131 of
#   16518 this
#   11857 flavor
#   10716 my
#   10531 in
#   10107 was
#    8449 1
#    8307 s
#    7945 bj
#    7796 for
#    7721 but
#    7007 The
#    6935 that
#    6921 so
