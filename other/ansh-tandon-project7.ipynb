# %% [markdown]
# # Project 7 -- Ansh Tandon

# %% [markdown]
# **TA Help:** John Smith, Alice Jones
#
# - Help with figuring out how to write a function.
#
# **Collaboration:** Friend1, Friend2
#
# - Helped figuring out how to load the dataset.
# - Helped debug error with my plot.

# %% [markdown]
# ## Question 1

# %%
# %%bash
# head /anvil/projects/tdm/data/iowa_liquor_sales/iowa_liquor_sales_cleaner.txt
# Out:
# Invoice/Item Number;Date;Store Number;Store Name;Address;City;Zip Code;Store Location;County Number;County;Category;Category Name;Vendor Number;Vendor Name;Item Number;Item Description;Pack;Bottle Volume (ml);State Bottle Cost;State Bottle Retail;Bottles Sold;Sale (Dollars);Volume Sold (Liters);Volume Sold (Gallons)
# S07122800016;08/16/2012;2846;CVS PHARMACY #8443 / CEDAR RAPIDS;3419 16TH AVE SW;CEDAR RAPIDS;52404;POINT (-91.716615 41.963516);57;LINN;1012100;CANADIAN WHISKIES;55;SAZERAC NORTH AMERICA;12408;CANADIAN LTD WHISKY;6;1750;8.99;13.49;3;40.47;5.25;1.39
# S21151400007;09/10/2014;3894;SMOKIN' JOE'S #6 TOBACCO AND LIQUOR;1404  1ST AVE NE;CEDAR RAPIDS;52402;POINT (-91.6537 41.987286);57;LINN;1031080;VODKA 80 PROOF;434;LUXCO-ST LOUIS;36306;HAWKEYE VODKA;12;750;3.34;5.01;12;60.12;9;2.38
# ...

# %%
# %%bash
# awk -F';' '{sales[$4] += $22; sales[$4] += 1} END{for (i in sales) {print sales[i] " at " i}}' /anvil/projects/tdm/data/iowa_liquor_sales/iowa_liquor_sales_cleaner.txt | sort -g | tail -10
# Out:
# 2.699e+07 at CENTRAL CITY LIQUOR, INC.
# 2.79722e+07 at SAM'S CLUB 8238 / DAVENPORT
# 3.10092e+07 at LOT-A-SPIRITS
# 3.39216e+07 at WILKIE LIQUORS
# 3.4387e+07 at BENZ DISTRIBUTING
# 3.96659e+07 at SAM'S CLUB 6344 / WINDSOR HEIGHTS
# 4.14426e+07 at SAM'S CLUB 8162 / CEDAR RAPIDS
# 4.89102e+07 at HY-VEE WINE AND SPIRITS / IOWA CITY
# 1.08519e+08 at CENTRAL CITY 2
# 1.23536e+08 at HY-VEE #3 / BDI / DES MOINES

# %% [markdown]
# Markdown notes and sentences and analysis written here.

# %% [markdown]
# ## Question 2

# %%
# %%bash
# awk -F'|' '{ mydonations[$10] += $15 } END { for (state in mydonations) print mydonations[state], state }' /anvil/projects/tdm/data/election/itcont1980.txt | sort -n | tail -10
# Out:
# 5328197 CT
# 5689543 DC
# 5705339 PA
# 7237330 OH
# 9105545 IL
# 10514203 FL
# 17916669
# 18673301 NY
# 24085171 CA
# 24472610 TX

# %% [markdown]
# Markdown notes and sentences and analysis written here.

# %% [markdown]
# ## Question 3

# %%
# %%bash
# awk -F, '{score[$3] += $NF; count[$3] += 1} END{for (i in score) {if (score[i] / count[i] == 5) print i}}' /anvil/projects/tdm/data/beer/reviews_sample.csv | sort -n | tail
# Out:
# 2001-04-26
# 2001-06-18
# 2002-01-26

# %% [markdown]
# Markdown notes and sentences and analysis written here.

# %% [markdown]
# ## Question 4

# %%
# %%bash
# awk -F',' '{ spend[$7] += $5 } END { for (region in spend) print region, spend[region] }' /anvil/projects/tdm/data/8451/The_Complete_Journey_2_Master/5000_transactions.csv
# Out:
# STORE_R 0
# WEST    9.68011e+06
# SOUTH   7.95792e+06
# EAST    1.16994e+07
# CENTRAL 8.89731e+06

# %% [markdown]
# Markdown notes and sentences and analysis written here.

# %% [markdown]
# ## Question 5

# %%
# %%bash
# grep 'EWR\|JFK\|LGA' | awk -F',' '{ if ($17 != "" && $16 != "") { totaldelays[$17] += $16; counts[$17]++ } } END { for (airport in totaldelays) print airport, totaldelays[airport] / counts[airport] }'
# Out:
# LGA 8.43934
# EWR 9.00959
# JFK 11.7693

# %% [markdown]
# Markdown notes and sentences and analysis written here.

# %% [markdown]
# ## Pledge
#
# By submitting this work I hereby pledge that this is my own, personal work. I've acknowledged in the designated place at the top of this file all sources that I used to complete said work, including but not limited to: online resources, books, and electronic communications. I've noted all collaboration with fellow students and/or TA's. I did not copy or plagiarize another's work.
#
# > As a Boilermaker pursuing academic excellence, I pledge to be honest and true in all that I do. Accountable together – We are Purdue.
