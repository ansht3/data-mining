# %% [markdown]
# # Project 9 -- Ansh Tandon

# %% [markdown]
# **TA Help:** John Smith, Alice Jones
#
# - Help with figuring out how to write a function.
#
# **Collaboration:** Friend1, Friend2
#
# - Helped figuring out how to load the dataset.
# - Helped debug error with my plot.

# %% [markdown]
# ## Question 1

# %%
# %sql sqlite:////anvil/projects/tdm/data/lahman/lahman.db

# %%
# %sql SELECT p.playerID, SUM(b.H) AS H, SUM(b.HR) AS HR, p.nameFirst, p.nameLast  FROM People AS p INNER JOIN Batting AS b ON p.playerID = b.playerID WHERE b.yearID = 2023 AND b.teamID = 'CHN' GROUP BY p.playerID
# Out:
#  * sqlite:////anvil/projects/tdm/data/lahman/lahman.db
# Done.
# [('alzolad01', 0, 0, 'Adbert', 'Alzolay'),
#  ('amayami01', 28, 5, 'Miguel', 'Amaya'),
#  ('assadja01', 0, 0, 'Javier', 'Assad'),
#  ('barnhtu01', 22, 1, 'Tucker', 'Barnhart'),
#  ('bellico01', 153, 26, 'Cody', 'Bellinger'),
#  ('boxbebr01', 0, 0, 'Brad', 'Boxberger'),
#  ('burdini01', 0, 0, 'Nick', 'Burdi'),
#  ('canaral01', 5, 1, 'Alexander', 'Canario'),
#  ('candeje01', 32, 6, 'Jeimer', 'Candelario'),
#  ('crowape01', 0, 0, 'Pete', 'Crow-Armstrong'),
#  ('cuasjo01', 0, 0, 'Jose', 'Cuas'),
#  ('duffety01', 0, 0, 'Tyler', 'Duffey'),
#  ('estraje01', 0, 0, 'Jeremiah', 'Estrada'),
#  ('fulmemi01', 0, 0, 'Michael', 'Fulmer'),
#  ('gomesya01', 102, 10, 'Yan', 'Gomes'),
#  ('greensh02', 0, 0, 'Shane', 'Greene'),
#  ('happia01', 144, 21, 'Ian', 'Happ'),
#  ('hendrky01', 0, 0, 'Kyle', 'Hendricks'),
#  ('hoernni01', 175, 9, 'Nico', 'Hoerner'),
#  ('hosmeer01', 22, 2, 'Eric', 'Hosmer'),
# ...

# %% [markdown]
# Markdown notes and sentences and analysis written here.

# %% [markdown]
# ## Question 2

# %%
# %sql SELECT b.playerID, SUM(b.HR) AS HR FROM Batting AS b  JOIN Pitching AS p  ON b.playerID = p.playerID  AND b.yearID = p.yearID  AND b.stint = p.stint WHERE b.yearID = 2023 GROUP BY b.playerID HAVING SUM(b.HR) > 30
# Out:
#  * sqlite:////anvil/projects/tdm/data/lahman/lahman.db
# Done.
# [('ohtansh01', 44)]

# %% [markdown]
# Markdown notes and sentences and analysis written here.

# %% [markdown]
# ## Question 3

# %%
# %sql SELECT p.playerID, p.nameFirst, p.nameLast, SUM(b.R) AS total_runs, SUM(b.SB) AS total_stolen_bases FROM People AS p JOIN Batting AS b ON p.playerID = b.playerID WHERE p.nameFirst = 'Rickey' AND p.nameLast = 'Henderson' GROUP BY p.playerID
# Out:
#  * sqlite:////anvil/projects/tdm/data/lahman/lahman.db
# Done.
# [('henderi01', 'Rickey', 'Henderson', 2295, 1406)]

# %% [markdown]
# Markdown notes and sentences and analysis written here.

# %% [markdown]
# ## Question 4

# %%
# %sql SELECT p.playerID, SUM(b.H) AS total_hits, p.nameFirst, p.nameLast FROM People AS p JOIN Batting AS b ON p.playerID = b.playerID GROUP BY p.playerID ORDER BY total_hits DESC LIMIT 5
# Out:
#  * sqlite:////anvil/projects/tdm/data/lahman/lahman.db
# Done.
# [('rosepe01', 4256, 'Pete', 'Rose'),
#  ('cobbty01', 4189, 'Ty', 'Cobb'),
#  ('aaronha01', 3771, 'Hank', 'Aaron'),
#  ('musiast01', 3630, 'Stan', 'Musial'),
#  ('speaktr01', 3514, 'Tris', 'Speaker')]

# %%
# %sql SELECT p.playerID, SUM(b.HR) AS total_home_runs, p.nameFirst, p.nameLast FROM People AS p JOIN Batting AS b ON p.playerID = b.playerID GROUP BY p.playerID ORDER BY total_home_runs DESC LIMIT 5
# Out:
#  * sqlite:////anvil/projects/tdm/data/lahman/lahman.db
# Done.
# [('bondsba01', 762, 'Barry', 'Bonds'),
#  ('aaronha01', 755, 'Hank', 'Aaron'),
#  ('ruthba01', 714, 'Babe', 'Ruth'),
#  ('pujolal01', 703, 'Albert', 'Pujols'),
#  ('rodrial01', 696, 'Alex', 'Rodriguez')]

# %% [markdown]
# Markdown notes and sentences and analysis written here.

# %% [markdown]
# ## Question 5

# %%
# %sql SELECT DISTINCT p.playerID, p.nameFirst, p.nameLast FROM CollegePlaying AS c JOIN People AS p ON c.playerID = p.playerID WHERE c.schoolID = 'purdue'
# Out:
#  * sqlite:////anvil/projects/tdm/data/lahman/lahman.db
# Done.
# [('allenje01', 'Jermaine', 'Allensworth'),
#  ('allenbe01', 'Bernie', 'Allen'),
#  ('buentja01', 'Jay', 'Buente'),
#  ('cianfar01', 'Archi', 'Cianfrocco'),
#  ('fehridu01', 'Dutch', 'Fehring'),
#  ('gassnda01', 'Dave', 'Gassner'),
#  ('kellysp01', 'Speed', 'Kelly'),
#  ('kinzema01', 'Matt', 'Kinzer'),
#  ('lindbjo01', 'Josh', 'Lindblom'),
#  ('mackife01', 'Felix', 'Mackiewicz'),
#  ('mccabjo01', 'Joe', 'McCabe'),
#  ('rossyri01', 'Rico', 'Rossy'),
#  ('skowrbi01', 'Bill', 'Skowron'),
#  ('tragewa01', 'Walt', 'Tragesser'),
#  ('wisehu01', 'Hughie', 'Wise')]

# %% [markdown]
# Markdown notes and sentences and analysis written here.

# %% [markdown]
# ## Pledge
#
# By submitting this work I hereby pledge that this is my own, personal work. I've acknowledged in the designated place at the top of this file all sources that I used to complete said work, including but not limited to: online resources, books, and electronic communications. I've noted all collaboration with fellow students and/or TA's. I did not copy or plagiarize another's work.
#
# > As a Boilermaker pursuing academic excellence, I pledge to be honest and true in all that I do. Accountable together – We are Purdue.
